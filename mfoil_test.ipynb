# %%
from utils.mfoil_notex import mfoil, plot_cpplus, plot_results, plot_airfoil
from utils.dat_extractor import extract_coordinates_from_dat_file
import numpy as np

coordinates = extract_coordinates_from_dat_file('data/NACA0012.dat')
coordinates = np.array(coordinates)
m = mfoil(coordinates)
m.setoper(alpha=7, Re=1e6, visc=False)
m.param.verb = 0
m.solve()

# %%
m.post.cl
# Out:
# 0.020399778972894862

# %%
m.post.cm
# Out:
# 0.0022828087161940224

# %%
m.post.cd
# Out:
# 0

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2, 1)
plot_cpplus(ax[0], m)
plot_airfoil(ax[1], m)
