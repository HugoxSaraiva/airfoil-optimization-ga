# %%
from utils.bezier_parsec_parametrization import BezierParsecAirfoil
import numpy as np

airfoil = BezierParsecAirfoil.get_random_airfoil()
print(airfoil)
from matplotlib import pyplot as plt

coordinates = airfoil.get_coordinates()

thickness_control_points = airfoil.thickess_curves[0].control_points + airfoil.thickess_curves[1].control_points
camber_control_points = airfoil.camber_curves[0].control_points + airfoil.camber_curves[1].control_points

fig, axs = plt.subplots(3, figsize=(10, 10))

t = np.linspace(0, 1, 100)
thickness_values = [airfoil.thickness_at(t_i) for t_i in t]
camber_values = [airfoil.camber_at(t_i) for t_i in t]
axs[0].plot([thickness[0] for thickness in thickness_values], [thickness[1] for thickness in thickness_values])
axs[0].plot([coord[0] for coord in thickness_control_points], [coord[1] for coord in thickness_control_points], 'or')
axs[1].plot([camber[0] for camber in camber_values], [camber[1] for camber in camber_values])
axs[1].plot([coord[0] for coord in camber_control_points], [coord[1] for coord in camber_control_points], 'or')
axs[2].plot([coord[0] for coord in coordinates], [coord[1] for coord in coordinates])
# Out:
# rc_candidates=[-0.4059425423598358, 0.038427449100463244]
# rc_candidates=[0.038427449100463244]
# rc_candidates=[-0.4059425423598358, 0.038427449100463244]
# rc_candidates=[0.038427449100463244]
# BezierParsecAirfoil(
#             r_le=-0.03315205441896338,
#             alpha_te=0.07272355780134654,
#             beta_te=0.02080280269404348,
#             z_te=0.003100156518025201,
#             gamma_le=0.0780458657814824,
#             x_c=0.4999431454931122,
#             y_c=0.03842924177768368,
#             k_c=-0.03401013783417678,
#             x_t=0.36419188084215237,
#             y_t=0.05850232288148627,
#             k_t=-0.09414630216396991,
#             dz_te=0.0003427517496668
#             )

# %%
print(thickness_control_points)
# Out:
# [(0, 0), (0, 0.049411078793001814), (0.11046621771764283, 0.05850232288148627), (0.36419188084215237, 0.05850232288148627), (0.36419188084215237, 0.05850232288148627), (0.6179175439666619, 0.05850232288148627), (-1.3583960943416389, 0.049411078793001814), (1, 0.0003427517496668)]

# %%
print(camber_control_points)
# Out:
# [(0, 0), (0.49136997163043, 0.038427449100463244), (0.4940152406383175, 0.03842924177768368), (0.4999431454931122, 0.03842924177768368), (0.4999431454931122, 0.03842924177768368), (0.5058710503479069, 0.03842924177768368), (0.5150815910495687, 0.038427449100463244), (1, 0.003100156518025201)]
